# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd  # Import the Pandas library for data manipulation
import matplotlib.pyplot as plt  # Import the Matplotlib library for creating plots
import seaborn as sns  # Import the Seaborn library for data visualization

# %%
# Read the data from the CSV file
df1 = pd.read_csv("/content/drive/My Drive/Time Series Plots/Annual Dengue Incidence.csv")

# Extract the year and Dengue Incidence data
x = df1['Year']
y = df1['Dengue Incidence']

# Create the bar plot
plt.figure(figsize=(15, 6))  # Adjust the figure size as needed
plt.bar(x, y, width=0.5, color='b', align='center')
plt.title("Time Series Plot of Dengue Incidence", fontsize=15)
plt.xlabel("Year", fontsize=14)
plt.ylabel("Dengue Incidence", fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Set x-ticks to display all years
plt.xticks(x, rotation=45, ha='right')

# Add data labels above the bars
for i, v in enumerate(y):
    plt.text(x[i], v + 50, str(v), ha='center', va='bottom')

# Show or save the plot
plt.tight_layout()
plt.show()  # Display the plot in the Python environment

# %%
# Read the data from the CSV file
df1 = pd.read_csv("/content/drive/My Drive/Time Series Plots/Annual Dengue Incidence.csv")

# Extract the year and Dengue Incidence data
x = df1['Year']
y = df1['Dengue Incidence']

# Create the line plot
plt.figure(figsize=(15, 6))  # Adjust the figure size as needed
plt.plot(x, y, marker='o', color='b', linestyle='-', markersize=8)
plt.title("Time Series Plot of Dengue Incidence", fontsize=20)
plt.xlabel("Year", fontsize=16)
plt.ylabel("Dengue Incidence", fontsize=16)
plt.grid(True, linestyle='--', alpha=0.7)

# Set x-ticks to display all years
plt.xticks(x, rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()  # Display the plot in the Python environment

# %%
# Read the data from the CSV file
df2 = pd.read_csv("/content/drive/My Drive/Time Series Plots/Annual Average Precipitation.csv")

# Extract the year and Dengue Incidence data
x = df2['Year']
y = df2['Precipitation']

# Create the bar plot
plt.figure(figsize=(15, 6))  # Adjust the figure size as needed
plt.bar(x, y, width=0.5, color='b', align='center')
plt.title("Time Series Plot of Annual Precipitation", fontsize=20)
plt.xlabel("Year", fontsize=16)
plt.ylabel("Average Precipitation (mm/Day)", fontsize=16)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Set x-ticks to display all years
plt.xticks(x, rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()  # Display the plot in the Python environment

# %%
# Read the data from the CSV file
df1 = pd.read_csv("/content/drive/My Drive/Time Series Plots/Annual Average Precipitation.csv")

# Extract the year and Dengue Incidence data
x = df1['Year']
y = df1['Precipitation']

# Create the line plot
plt.figure(figsize=(15, 6))  # Adjust the figure size as needed
plt.plot(x, y, marker='o', color='b', linestyle='-', markersize=8)
plt.title("Time Series Plot of Annual precipitation", fontsize=20)
plt.xlabel("Year", fontsize=16)
plt.ylabel("Average Precipitation (mm/Day)", fontsize=16)
plt.grid(True, linestyle='--', alpha=0.7)

# Set x-ticks to display all years
plt.xticks(x, rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()  # Display the plot in the Python environment

# %%
# Read the data from the CSV file
df3 = pd.read_csv("/content/drive/My Drive/Time Series Plots/Annual Relative Humidity at 2 Meters.csv")

# Extract the year and Dengue Incidence data
x = df3['Year']
y = df3['Humidity']

# Create the bar plot
plt.figure(figsize=(15, 6))  # Adjust the figure size as needed
plt.bar(x, y, width=0.5, color='b', align='center')
plt.title("Time Series Plot of Annual Relative Humidity", fontsize=20)
plt.xlabel("Year", fontsize=16)
plt.ylabel("Relative Humidity at 2 meters", fontsize=16)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Set x-ticks to display all years
plt.xticks(x, rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()  # Display the plot in the Python environment

# %%
# Read the data from the CSV file
df1 = pd.read_csv("/content/drive/My Drive/Time Series Plots/Annual Relative Humidity at 2 Meters.csv")

# Extract the year and Dengue Incidence data
x = df1['Year']
y = df1['Humidity']

# Create the line plot
plt.figure(figsize=(15, 6))  # Adjust the figure size as needed
plt.plot(x, y, marker='o', color='b', linestyle='-', markersize=8)
plt.title("Time Series Plot of Annual Relative Humidity", fontsize=20)
plt.xlabel("Year", fontsize=16)
plt.ylabel("Relative Humidity at 2 meters", fontsize=16)
plt.grid(True, linestyle='--', alpha=0.7)

# Set x-ticks to display all years
plt.xticks(x, rotation=45, ha='right')

# Show the plot
plt.tight_layout()

# %%
# Read the data from the CSV file
df4 = pd.read_csv("/content/drive/My Drive/Time Series Plots/Annual Temperature at 2 Meters.csv")

# Extract the year and Dengue Incidence data
x = df4['Year']
y = df4['Temperature']

# Create the bar plot
plt.figure(figsize=(15, 6))  # Adjust the figure size as needed
plt.bar(x, y, width=0.5, color='b', align='center')
plt.title("Time Series Plot of Annual Temperature", fontsize=20)
plt.xlabel("Year", fontsize=16)
plt.ylabel("Temperature at 2 meters (°C)", fontsize=16)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Set x-ticks to display all years
plt.xticks(x, rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()  # Display the plot in the Python environment

# %%
# Read the data from the CSV file
df1 = pd.read_csv("/content/drive/My Drive/Time Series Plots/Annual Temperature at 2 Meters.csv")

# Extract the year and Dengue Incidence data
x = df1['Year']
y = df1['Temperature']

# Create the line plot
plt.figure(figsize=(15, 6))  # Adjust the figure size as needed
plt.plot(x, y, marker='o', color='b', linestyle='-', markersize=8)
plt.title("Time Series Plot of Annual Temperature", fontsize=20)
plt.xlabel("Year", fontsize=16)
plt.ylabel("Temperature at 2 meters (°C)", fontsize=16)
plt.grid(True, linestyle='--', alpha=0.7)

# Set x-ticks to display all years
plt.xticks(x, rotation=45, ha='right')

# Show the plot
plt.tight_layout()
